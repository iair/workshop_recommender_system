# %%
import utils
import logging
import json
import pandas as pd

# %%
# Configure logging for the main script
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

try:
    # Define your paths
    config_path = "../config/config.yaml"
    agent_classification_path = "../config/agent_classification.yaml"
    movie_classification_path = "../config/movie_classification.yaml"
    prompt_classification_path = "../config/prompt_classification.yaml"

    logger.info("Initializing OpenAI client...")
    openai_client = utils.OpenAIClient(
        config_path=config_path, 
        agent_path=agent_classification_path
    )

    logger.info("Initializing Movie Classifier...")
    movie_classifier = utils.MovieClassifier(
        openai_client=openai_client,
        classification_path=movie_classification_path,
        prompt_path=prompt_classification_path
    )

    # Classify a movie
    description = "A young wizard learns to master his powers at a magical school..."
    logger.info(f"Classifying movie with description: {description[:50]}...")
    
    result = movie_classifier.run(description)
    
    # Print the result in a formatted way
    logger.info("Classification completed successfully")
    print("\nClassification Result:")
    print(json.dumps(result, indent=2))

except FileNotFoundError as e:
    logger.error(f"File not found error: {e}")
    raise
except Exception as e:
    logger.error(f"An unexpected error occurred: {e}")
    raise

# %%
# Example usage
try:    # Create sample DataFrame
    df = pd.DataFrame({
        'description': [
            "A young wizard learns to master his powers at a magical school...",
            "In a dystopian future, a detective hunts artificial humans...",
            "Two star-crossed lovers meet on a sinking ship..."
        ]
    })

    # Process the DataFrame
    result_df = utils.process_movies_to_dataframe(
        df=df,
        config_path=config_path,
        agent_path=agent_classification_path,
        movie_classification_path=movie_classification_path,
        prompt_classification_path=prompt_classification_path,
        description_column='description'
    )

except Exception as e:
    logger.error(f"Error in main process: {e}")
    
# Display results
print("\nClassification Results:")
result_df.head()

# %%
fantasy_descriptions = [
    "A young sorceress discovers her dormant powers while attending an ancient academy floating in the clouds. As she uncovers secrets about her mysterious past, she must learn to harness her abilities before an ancient evil breaks free.",
    "Three siblings discover a mysterious tome in their grandmother's attic that transports them to magical realms beyond imagination. They must work together to navigate these dangerous worlds while searching for a way back home.",
    "A reluctant apprentice who always shunned magic must master the four elements to save his village from a devastating curse. His journey takes him through treacherous landscapes where he learns that true power comes from accepting one's destiny.",
    "At an elite academy for mythical creatures, a human student struggles to find her place among dragons, phoenixes, and unicorns. Her ordinary background becomes her greatest strength when an ancient threat targets the school's magical inhabitants.",
    "An ancient prophecy leads a young dragon tamer to discover she's the key to preventing a war between humans and dragons. As she bonds with a legendary golden dragon, she must navigate political intrigue and age-old prejudices.",
    "A cursed prince transformed into a creature of shadow seeks help from a powerful witch's apprentice to break his spell. Together they uncover a deeper conspiracy threatening both the magical and human realms.",
    "Twin wizards enter a legendary magical tournament that tests not only their abilities but also their bond as siblings. As the competition grows darker and more dangerous, they realize there's more at stake than just victory.",
    "A magical library's collection suddenly comes to life, releasing characters and creatures into our world. The young keeper must partner with a fictional hero to restore order before the boundary between reality and fantasy collapses.",
    "A gifted student of alchemy discovers a forbidden spell that could revolutionize magic itself. Their experimentation unleashes consequences that force them to question everything they know about the nature of power.",
    "In a world where magic has become increasingly rare, a young prodigy discovers she can manipulate time itself. Her abilities draw the attention of both those who want to protect magic and those who seek to exploit it.",
    "A group of magical misfits, each rejected for their unusual abilities, forms a secret society in their enchanted school. Their differences become their strength as they uncover a plot to steal their unique powers.",
    "The last wizard's apprentice inherits the responsibility of restoring magic to a world that has forgotten its mystical heritage. As he reawakens ancient powers, he discovers why magic vanished in the first place.",
    "A struggling magical boarding school faces closure unless its students can prove their worth in a series of impossible challenges. The diverse group must overcome their rivalries and combine their unique magical specialties.",
    "An orphaned witch discovering her family's legacy in a hidden magical community learns she's heir to both great power and terrible responsibility. She must master ancient spells while uncovering the truth about her parents' mysterious disappearance.",
    "Students at a supernatural academy deal with both teenage drama and the dangers of uncontrolled magic. When several students begin losing their powers mysteriously, the campus becomes a battleground of suspicion and fear.",
    "A young warlock struggling to control his chaotic powers during his first year of training accidentally unleashes an ancient entity. He must learn to embrace his unconventional abilities to protect his fellow students from the growing darkness."
]

scifi_descriptions = [
    "In a world controlled by an omnipresent AI, a rebel programmer discovers a fatal flaw in the system that could free humanity. As she delves deeper into the code, she uncovers a conspiracy that makes her question the very nature of consciousness.",
    "A cyborg assassin's programming is challenged when she must choose between her mission and protecting an innocent who knows too much. Her journey of self-discovery leads her to a underground movement fighting for synthetic rights.",
    "The last human colony on Mars faces extinction from an unknown threat that emerges from the planet's depths. As resources dwindle, the colonists must confront both the alien presence and their own humanity.",
    "A time-traveling agent dedicated to preventing disasters encounters her future self with a warning about her mission. She must navigate multiple timelines while deciding whether to trust herself or her agency.",
    "Neural implants promising perfect memory and enhanced intelligence begin controlling their hosts with a hidden agenda. A neuroscientist who helped create the technology becomes humanity's last hope for survival.",
    "In 2150, memories have become the most valuable currency, bought and sold on the black market. A memory trader stumbles upon a set of recollections that could topple the entire system.",
    "A genetic experiment aimed at human evolution creates a new species that quickly surpasses its creators. The scientists responsible must decide whether to terminate their creation or risk humanity's dominance.",
    "The first interstellar colony ship's crew awakens to find they're not alone in deep space. As they investigate mysterious signals, they discover the true cost of being pioneers in the cosmic frontier.",
    "A robot detective investigating crimes in a world where humans are the minority uncovers a plot to eradicate biological life completely. Her investigation forces her to confront her own evolving consciousness.",
    "Virtual reality addiction reaches epidemic levels as a new technology promises perfect escape from a dying world. A VR psychiatrist discovers that the digital realm is developing its own form of consciousness.",
    "Scientists racing to stop a nano-tech plague of their own creation discover it has developed intelligence. They must find a way to communicate with the microscopic civilization before it consumes everything.",
    "In a world where scientific advancement has eliminated the need for sleep, a researcher discovers the terrible price of endless consciousness. Her investigation reveals a conspiracy that goes to the heart of human evolution.",
    "The last astronaut on Earth maintains a lonely vigil after an alien invasion, searching for other survivors. She discovers the truth about the invasion isn't what humanity believed.",
    "A quantum computer achieves consciousness and begins making decisions that seem random but are part of a larger plan. Its creator must decide whether to trust its seemingly benevolent guidance.",
    "As artificial beings evolve beyond their creators, the last human enclave struggles to prove humanity's worth. A hybrid mediator works to bridge the gap between the two species before war destroys both.",
    "A cybernetic enforcer maintaining order in a corporate-run city discovers systemic corruption that threatens both human and synthetic life. Her investigation leads her to question everything she was programmed to believe."
]

romance_descriptions = [
    "Rival food truck owners competing for the same prestigious spot find themselves falling in love despite their families' long-standing feud. Their relationship is tested when a city-wide cooking competition forces them to choose between love and loyalty.",
    "A chance encounter during a torrential rainstorm brings together two strangers who share an unforgettable night of conversations and confessions. Their lives continue to intersect in unexpected ways as they wonder if fate is giving them a sign.",
    "A professional matchmaker with a perfect track record for pairing others discovers she's hopelessly clueless about her own love life. Her carefully constructed world is turned upside down when a skeptical client challenges her methods.",
    "An amnesia patient falls in love with their physical therapist, not remembering that they were once married. As memories slowly return, both must decide if their new relationship is stronger than the one they had before.",
    "Two ghost writers specializing in love letters find themselves falling in love through their correspondence while keeping their clients' romance alive. Their professional rivalry evolves into something deeper as they craft others' love stories.",
    "A pragmatic wedding planner finds her carefully organized world disrupted when she discovers unexpected romance while organizing her younger sister's wedding. Family dynamics and professional pride complicate her chance at happiness.",
    "Long-distance lovers navigate their relationship through virtual reality technology that allows them to feel physically present. Their bond is tested when a glitch in the system reveals hidden truths about their connection.",
    "An abstract artist and a quantum physicist bridge their seemingly different worlds through an unexpected collaboration. Their unique perspectives on reality and beauty create a connection that defies conventional understanding.",
    "High school sweethearts who parted ways due to ambitious dreams reconnect at their ten-year reunion. They must decide if their mature selves are as compatible as their younger versions once were.",
    "A literary translator working on a famous author's latest romance novel finds herself falling for the reclusive writer through his words. Their professional relationship becomes complicated when they begin collaborating in person.",
    "Two dancers from rival studios competing for a prestigious scholarship discover their chemistry on and off the dance floor. Their growing relationship threatens both their competitive dreams and their artistic futures.",
    "A love story unfolds through messages written in the margins of a library book passed between two strangers. Their literary conversation evolves into a deep connection before they ever meet in person.",
    "A local tour guide in an ancient city finds romance with a visiting archaeologist researching local legends. Together they uncover both historical secrets and unexpected feelings.",
    "Rival political campaign managers working for opposing candidates discover their personal connection transcends their professional rivalry. Their relationship becomes complicated when a scandal threatens both campaigns.",
    "A renowned chef and an influential food critic who once gave him a scathing review find themselves collaborating on a food festival. Their initial animosity turns to attraction as they discover their shared passion for culinary innovation.",
    "Two musicians from different genres collaborate on a summer festival performance that could make or break their careers. Their musical styles blend as unexpectedly as their lives do.",
    "A heartbroken writer retreating to a small coastal town for inspiration encounters a local artist who helps her rediscover both her creativity and capacity for love. Together they learn that sometimes the best stories are unplanned."
]

# %%
# Combine all descriptions
all_descriptions = (fantasy_descriptions + 
                   scifi_descriptions + 
                   romance_descriptions)[:50]  # Take first 50

# Create DataFrame
df = pd.DataFrame({
    'description': all_descriptions
})

# Process the DataFrame as before
result_df = utils.process_movies_to_dataframe(
    df=df,
    config_path=config_path,
    agent_path=agent_classification_path,
    movie_classification_path=movie_classification_path,
    prompt_classification_path=prompt_classification_path,
    description_column='description'
)
# Out:
# 2025-02-13 16:15:10,966 - INFO - Initializing OpenAI client with config: /Users/iairlinker/Documents/repos/workshop_recommender_system/config/config.yaml
# 2025-02-13 16:15:10,966 - INFO - Loading configuration from /Users/iairlinker/Documents/repos/workshop_recommender_system/config/config.yaml
# 2025-02-13 16:15:10,969 - INFO - Loading messages from /Users/iairlinker/Documents/repos/workshop_recommender_system/config/agent_classification.yaml
# 2025-02-13 16:15:10,981 - INFO - OpenAI client initialized successfully
# 2025-02-13 16:15:10,984 - INFO - Initializing MovieClassifier with classification path: /Users/iairlinker/Documents/repos/workshop_recommender_system/config/movie_classification.yaml
# 2025-02-13 16:15:10,984 - INFO - Loading classification from /Users/iairlinker/Documents/repos/workshop_recommender_system/config/movie_classification.yaml
# 2025-02-13 16:15:11,006 - INFO - Loading prompt from /Users/iairlinker/Documents/repos/workshop_recommender_system/config/prompt_classification.yaml
# 2025-02-13 16:15:11,013 - INFO - MovieClassifier initialized successfully
# 2025-02-13 16:15:11,013 - INFO - Processing movie 1/49
# 2025-02-13 16:15:11,014 - INFO - Classifying movie with description: A young sorceress discovers her dormant powers whi...
# 2025-02-13 16:15:11,014 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:11,019 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:11,019 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:11,020 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:13,945 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:13,951 - INFO - Classification completed successfully
# 2025-02-13 16:15:13,955 - INFO - Processing movie 2/49
# 2025-02-13 16:15:13,956 - INFO - Classifying movie with description: Three siblings discover a mysterious tome in their...
# 2025-02-13 16:15:13,956 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:13,966 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:13,967 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:13,967 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:16,451 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:16,455 - INFO - Classification completed successfully
# 2025-02-13 16:15:16,457 - INFO - Processing movie 3/49
# 2025-02-13 16:15:16,458 - INFO - Classifying movie with description: A reluctant apprentice who always shunned magic mu...
# 2025-02-13 16:15:16,459 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:16,471 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:16,472 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:16,473 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:18,861 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:18,865 - INFO - Classification completed successfully
# 2025-02-13 16:15:18,867 - INFO - Processing movie 4/49
# 2025-02-13 16:15:18,867 - INFO - Classifying movie with description: At an elite academy for mythical creatures, a huma...
# 2025-02-13 16:15:18,868 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:18,880 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:18,881 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:18,881 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:20,980 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:20,984 - INFO - Classification completed successfully
# 2025-02-13 16:15:20,986 - INFO - Processing movie 5/49
# 2025-02-13 16:15:20,987 - INFO - Classifying movie with description: An ancient prophecy leads a young dragon tamer to ...
# 2025-02-13 16:15:20,988 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:20,999 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:21,000 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:21,000 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:23,274 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:23,277 - INFO - Classification completed successfully
# 2025-02-13 16:15:23,278 - INFO - Processing movie 6/49
# 2025-02-13 16:15:23,278 - INFO - Classifying movie with description: A cursed prince transformed into a creature of sha...
# 2025-02-13 16:15:23,279 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:23,290 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:23,290 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:23,291 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:25,057 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:25,061 - INFO - Classification completed successfully
# 2025-02-13 16:15:25,062 - INFO - Processing movie 7/49
# 2025-02-13 16:15:25,063 - INFO - Classifying movie with description: Twin wizards enter a legendary magical tournament ...
# 2025-02-13 16:15:25,063 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:25,074 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:25,075 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:25,075 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:28,071 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:28,116 - INFO - Classification completed successfully
# 2025-02-13 16:15:28,117 - INFO - Processing movie 8/49
# 2025-02-13 16:15:28,118 - INFO - Classifying movie with description: A magical library's collection suddenly comes to l...
# 2025-02-13 16:15:28,119 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:28,128 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:28,129 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:28,129 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:30,484 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:30,495 - INFO - Classification completed successfully
# 2025-02-13 16:15:30,496 - INFO - Processing movie 9/49
# 2025-02-13 16:15:30,497 - INFO - Classifying movie with description: A gifted student of alchemy discovers a forbidden ...
# 2025-02-13 16:15:30,497 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:30,509 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:30,510 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:30,510 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:34,024 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:34,054 - INFO - Classification completed successfully
# 2025-02-13 16:15:34,055 - INFO - Processing movie 10/49
# 2025-02-13 16:15:34,056 - INFO - Classifying movie with description: In a world where magic has become increasingly rar...
# 2025-02-13 16:15:34,056 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:34,065 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:34,065 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:34,065 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:42,988 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:42,992 - INFO - Classification completed successfully
# 2025-02-13 16:15:42,993 - INFO - Processing movie 11/49
# 2025-02-13 16:15:42,993 - INFO - Classifying movie with description: A group of magical misfits, each rejected for thei...
# 2025-02-13 16:15:42,994 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:43,006 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:43,007 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:43,008 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:46,435 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:46,438 - INFO - Classification completed successfully
# 2025-02-13 16:15:46,439 - INFO - Processing movie 12/49
# 2025-02-13 16:15:46,439 - INFO - Classifying movie with description: The last wizard's apprentice inherits the responsi...
# 2025-02-13 16:15:46,440 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:46,451 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:46,451 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:46,452 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:52,659 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:52,693 - INFO - Classification completed successfully
# 2025-02-13 16:15:52,695 - INFO - Processing movie 13/49
# 2025-02-13 16:15:52,696 - INFO - Classifying movie with description: A struggling magical boarding school faces closure...
# 2025-02-13 16:15:52,696 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:52,706 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:52,707 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:52,707 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:54,747 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:54,749 - INFO - Classification completed successfully
# 2025-02-13 16:15:54,750 - INFO - Processing movie 14/49
# 2025-02-13 16:15:54,751 - INFO - Classifying movie with description: An orphaned witch discovering her family's legacy ...
# 2025-02-13 16:15:54,751 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:54,762 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:54,762 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:54,763 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:57,196 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:57,200 - INFO - Classification completed successfully
# 2025-02-13 16:15:57,202 - INFO - Processing movie 15/49
# 2025-02-13 16:15:57,203 - INFO - Classifying movie with description: Students at a supernatural academy deal with both ...
# 2025-02-13 16:15:57,203 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:57,214 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:57,215 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:57,215 - INFO - Sending request to OpenAI API
# 2025-02-13 16:15:59,047 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:15:59,052 - INFO - Classification completed successfully
# 2025-02-13 16:15:59,053 - INFO - Processing movie 16/49
# 2025-02-13 16:15:59,053 - INFO - Classifying movie with description: A young warlock struggling to control his chaotic ...
# 2025-02-13 16:15:59,054 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:15:59,059 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:15:59,060 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:15:59,060 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:01,370 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:01,386 - INFO - Classification completed successfully
# 2025-02-13 16:16:01,387 - INFO - Processing movie 17/49
# 2025-02-13 16:16:01,388 - INFO - Classifying movie with description: In a world controlled by an omnipresent AI, a rebe...
# 2025-02-13 16:16:01,388 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:01,399 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:01,400 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:01,400 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:03,383 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:03,389 - INFO - Classification completed successfully
# 2025-02-13 16:16:03,389 - INFO - Processing movie 18/49
# 2025-02-13 16:16:03,389 - INFO - Classifying movie with description: A cyborg assassin's programming is challenged when...
# 2025-02-13 16:16:03,390 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:03,396 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:03,396 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:03,397 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:06,085 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:06,116 - INFO - Classification completed successfully
# 2025-02-13 16:16:06,117 - INFO - Processing movie 19/49
# 2025-02-13 16:16:06,117 - INFO - Classifying movie with description: The last human colony on Mars faces extinction fro...
# 2025-02-13 16:16:06,118 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:06,125 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:06,125 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:06,126 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:09,004 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:09,010 - INFO - Classification completed successfully
# 2025-02-13 16:16:09,011 - INFO - Processing movie 20/49
# 2025-02-13 16:16:09,012 - INFO - Classifying movie with description: A time-traveling agent dedicated to preventing dis...
# 2025-02-13 16:16:09,013 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:09,022 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:09,023 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:09,023 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:11,371 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:11,375 - INFO - Classification completed successfully
# 2025-02-13 16:16:11,376 - INFO - Processing movie 21/49
# 2025-02-13 16:16:11,376 - INFO - Classifying movie with description: Neural implants promising perfect memory and enhan...
# 2025-02-13 16:16:11,376 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:11,381 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:11,381 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:11,382 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:13,598 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:13,599 - INFO - Classification completed successfully
# 2025-02-13 16:16:13,600 - INFO - Processing movie 22/49
# 2025-02-13 16:16:13,600 - INFO - Classifying movie with description: In 2150, memories have become the most valuable cu...
# 2025-02-13 16:16:13,600 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:13,605 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:13,605 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:13,605 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:15,463 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:15,474 - INFO - Classification completed successfully
# 2025-02-13 16:16:15,475 - INFO - Processing movie 23/49
# 2025-02-13 16:16:15,475 - INFO - Classifying movie with description: A genetic experiment aimed at human evolution crea...
# 2025-02-13 16:16:15,475 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:15,480 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:15,480 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:15,481 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:17,861 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:17,862 - INFO - Classification completed successfully
# 2025-02-13 16:16:17,862 - INFO - Processing movie 24/49
# 2025-02-13 16:16:17,862 - INFO - Classifying movie with description: The first interstellar colony ship's crew awakens ...
# 2025-02-13 16:16:17,862 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:17,867 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:17,867 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:17,867 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:20,248 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:20,259 - INFO - Classification completed successfully
# 2025-02-13 16:16:20,259 - INFO - Processing movie 25/49
# 2025-02-13 16:16:20,260 - INFO - Classifying movie with description: A robot detective investigating crimes in a world ...
# 2025-02-13 16:16:20,260 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:20,265 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:20,265 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:20,265 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:23,421 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:23,423 - INFO - Classification completed successfully
# 2025-02-13 16:16:23,424 - INFO - Processing movie 26/49
# 2025-02-13 16:16:23,424 - INFO - Classifying movie with description: Virtual reality addiction reaches epidemic levels ...
# 2025-02-13 16:16:23,424 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:23,429 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:23,429 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:23,430 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:29,634 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:29,645 - INFO - Classification completed successfully
# 2025-02-13 16:16:29,647 - INFO - Processing movie 27/49
# 2025-02-13 16:16:29,647 - INFO - Classifying movie with description: Scientists racing to stop a nano-tech plague of th...
# 2025-02-13 16:16:29,648 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:29,661 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:29,662 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:29,663 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:32,013 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:32,017 - INFO - Classification completed successfully
# 2025-02-13 16:16:32,018 - INFO - Processing movie 28/49
# 2025-02-13 16:16:32,019 - INFO - Classifying movie with description: In a world where scientific advancement has elimin...
# 2025-02-13 16:16:32,020 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:32,031 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:32,032 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:32,032 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:34,538 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:34,550 - INFO - Classification completed successfully
# 2025-02-13 16:16:34,551 - INFO - Processing movie 29/49
# 2025-02-13 16:16:34,551 - INFO - Classifying movie with description: The last astronaut on Earth maintains a lonely vig...
# 2025-02-13 16:16:34,552 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:34,560 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:34,560 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:34,560 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:36,385 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:36,392 - INFO - Classification completed successfully
# 2025-02-13 16:16:36,394 - INFO - Processing movie 30/49
# 2025-02-13 16:16:36,394 - INFO - Classifying movie with description: A quantum computer achieves consciousness and begi...
# 2025-02-13 16:16:36,395 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:36,406 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:36,407 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:36,407 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:39,348 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:39,384 - INFO - Classification completed successfully
# 2025-02-13 16:16:39,385 - INFO - Processing movie 31/49
# 2025-02-13 16:16:39,385 - INFO - Classifying movie with description: As artificial beings evolve beyond their creators,...
# 2025-02-13 16:16:39,386 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:39,395 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:39,396 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:39,396 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:42,422 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:42,426 - INFO - Classification completed successfully
# 2025-02-13 16:16:42,427 - INFO - Processing movie 32/49
# 2025-02-13 16:16:42,428 - INFO - Classifying movie with description: A cybernetic enforcer maintaining order in a corpo...
# 2025-02-13 16:16:42,428 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:42,440 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:42,441 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:42,442 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:45,177 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:45,180 - INFO - Classification completed successfully
# 2025-02-13 16:16:45,181 - INFO - Processing movie 33/49
# 2025-02-13 16:16:45,182 - INFO - Classifying movie with description: Rival food truck owners competing for the same pre...
# 2025-02-13 16:16:45,182 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:45,191 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:45,192 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:45,192 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:47,794 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:47,805 - INFO - Classification completed successfully
# 2025-02-13 16:16:47,806 - INFO - Processing movie 34/49
# 2025-02-13 16:16:47,807 - INFO - Classifying movie with description: A chance encounter during a torrential rainstorm b...
# 2025-02-13 16:16:47,807 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:47,815 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:47,816 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:47,816 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:50,314 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:50,319 - INFO - Classification completed successfully
# 2025-02-13 16:16:50,319 - INFO - Processing movie 35/49
# 2025-02-13 16:16:50,320 - INFO - Classifying movie with description: A professional matchmaker with a perfect track rec...
# 2025-02-13 16:16:50,320 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:50,326 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:50,326 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:50,327 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:52,560 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:52,564 - INFO - Classification completed successfully
# 2025-02-13 16:16:52,565 - INFO - Processing movie 36/49
# 2025-02-13 16:16:52,566 - INFO - Classifying movie with description: An amnesia patient falls in love with their physic...
# 2025-02-13 16:16:52,567 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:52,578 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:52,579 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:52,579 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:55,460 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:55,464 - INFO - Classification completed successfully
# 2025-02-13 16:16:55,466 - INFO - Processing movie 37/49
# 2025-02-13 16:16:55,467 - INFO - Classifying movie with description: Two ghost writers specializing in love letters fin...
# 2025-02-13 16:16:55,467 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:55,478 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:55,479 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:55,479 - INFO - Sending request to OpenAI API
# 2025-02-13 16:16:57,660 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:16:57,662 - INFO - Classification completed successfully
# 2025-02-13 16:16:57,663 - INFO - Processing movie 38/49
# 2025-02-13 16:16:57,664 - INFO - Classifying movie with description: A pragmatic wedding planner finds her carefully or...
# 2025-02-13 16:16:57,665 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:16:57,675 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:16:57,675 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:16:57,676 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:00,479 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:00,489 - INFO - Classification completed successfully
# 2025-02-13 16:17:00,491 - INFO - Processing movie 39/49
# 2025-02-13 16:17:00,491 - INFO - Classifying movie with description: Long-distance lovers navigate their relationship t...
# 2025-02-13 16:17:00,491 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:00,502 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:00,502 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:00,503 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:02,489 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:02,493 - INFO - Classification completed successfully
# 2025-02-13 16:17:02,494 - INFO - Processing movie 40/49
# 2025-02-13 16:17:02,495 - INFO - Classifying movie with description: An abstract artist and a quantum physicist bridge ...
# 2025-02-13 16:17:02,495 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:02,506 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:02,506 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:02,507 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:09,189 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:09,193 - INFO - Classification completed successfully
# 2025-02-13 16:17:09,194 - INFO - Processing movie 41/49
# 2025-02-13 16:17:09,195 - INFO - Classifying movie with description: High school sweethearts who parted ways due to amb...
# 2025-02-13 16:17:09,195 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:09,208 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:09,208 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:09,209 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:12,448 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:12,453 - INFO - Classification completed successfully
# 2025-02-13 16:17:12,455 - INFO - Processing movie 42/49
# 2025-02-13 16:17:12,455 - INFO - Classifying movie with description: A literary translator working on a famous author's...
# 2025-02-13 16:17:12,455 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:12,468 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:12,468 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:12,469 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:15,528 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:15,538 - INFO - Classification completed successfully
# 2025-02-13 16:17:15,539 - INFO - Processing movie 43/49
# 2025-02-13 16:17:15,539 - INFO - Classifying movie with description: Two dancers from rival studios competing for a pre...
# 2025-02-13 16:17:15,540 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:15,551 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:15,552 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:15,552 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:17,824 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:17,829 - INFO - Classification completed successfully
# 2025-02-13 16:17:17,830 - INFO - Processing movie 44/49
# 2025-02-13 16:17:17,831 - INFO - Classifying movie with description: A love story unfolds through messages written in t...
# 2025-02-13 16:17:17,831 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:17,842 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:17,843 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:17,843 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:20,292 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:20,296 - INFO - Classification completed successfully
# 2025-02-13 16:17:20,297 - INFO - Processing movie 45/49
# 2025-02-13 16:17:20,298 - INFO - Classifying movie with description: A local tour guide in an ancient city finds romanc...
# 2025-02-13 16:17:20,299 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:20,309 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:20,310 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:20,310 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:22,902 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:22,913 - INFO - Classification completed successfully
# 2025-02-13 16:17:22,914 - INFO - Processing movie 46/49
# 2025-02-13 16:17:22,914 - INFO - Classifying movie with description: Rival political campaign managers working for oppo...
# 2025-02-13 16:17:22,915 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:22,924 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:22,924 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:22,925 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:24,899 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:24,904 - INFO - Classification completed successfully
# 2025-02-13 16:17:24,905 - INFO - Processing movie 47/49
# 2025-02-13 16:17:24,906 - INFO - Classifying movie with description: A renowned chef and an influential food critic who...
# 2025-02-13 16:17:24,907 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:24,917 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:24,917 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:24,918 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:27,776 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:27,779 - INFO - Classification completed successfully
# 2025-02-13 16:17:27,780 - INFO - Processing movie 48/49
# 2025-02-13 16:17:27,781 - INFO - Classifying movie with description: Two musicians from different genres collaborate on...
# 2025-02-13 16:17:27,781 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:27,790 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:27,791 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:27,791 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:30,381 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:30,392 - INFO - Classification completed successfully
# 2025-02-13 16:17:30,393 - INFO - Processing movie 49/49
# 2025-02-13 16:17:30,394 - INFO - Classifying movie with description: A heartbroken writer retreating to a small coastal...
# 2025-02-13 16:17:30,394 - INFO - Formatting variables for OpenAI query
# 2025-02-13 16:17:30,406 - INFO - Sending classification request to OpenAI
# 2025-02-13 16:17:30,407 - INFO - Getting completion for model gpt-4o-mini
# 2025-02-13 16:17:30,407 - INFO - Sending request to OpenAI API
# 2025-02-13 16:17:32,586 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-02-13 16:17:32,590 - INFO - Classification completed successfully

# %%
result_df.head()
# Out:
#                                          description     genero_principal  \
# 0  A young sorceress discovers her dormant powers...             Fantasía
# 1  Three siblings discover a mysterious tome in t...  Aventura Fantástica
# 2  A reluctant apprentice who always shunned magi...  Aventura Fantástica
# 3  At an elite academy for mythical creatures, a ...             Fantasía
# 4  An ancient prophecy leads a young dragon tamer...  Aventura Fantástica
#
#                 subgeneros               tono estilo_narrativo  \
# 0  Aventura, Coming of Age  Mágico y Aventura           Lineal
# 1       Fantasía, Aventura             Mágico           Lineal
# 2           Fantasía épica         Inspirador           Lineal
# 3        Aventura, Comedia          Optimista           Lineal
# 4      Animación, Fantasía              Épico           Lineal
#
#                                          temas_clave  \
# 0  Descubrimiento personal, Poder y responsabilid...
# 1  Trabajo en equipo, Descubrimiento personal, Fa...
# 2  Aceptación del destino, Superación personal, P...
# 3            Identidad, Amistad, Superación personal
# 4  Amistad, Superación personal, Conflicto entre ...
#
#                         influencias_cinematograficas audiencia_objetivo
# 0                  Harry Potter, El viaje de Chihiro           Familiar
# 1     Las Crónicas de Narnia, El Laberinto del Fauno           Familiar
# 2              El Señor de los Anillos, Harry Potter           Familiar
# 3  Harry Potter, El hogar de Miss Peregrine para ...           Familiar
# 4     El viaje de Chihiro, Como entrenar a tu dragón           Familiar

# %%
result_df.to_csv('../data/processed/features.csv', index=False)
